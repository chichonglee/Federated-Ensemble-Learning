# %%
import sys
print(sys.executable)
# Out:
# /mnt/e/00_workspace/baseline_unmodified/FEL_TMD_VEN/Federated-Ensemble-Learning/venvs/tf15_py310/bin/python

# %%
# !pip3 list
# Out:
# Package                      Version
# ---------------------------- ------------
# absl-py                      2.3.1
# asttokens                    3.0.1
# astunparse                   1.6.3
# cachetools                   6.2.2
# certifi                      2025.11.12
# charset-normalizer           3.4.4
# comm                         0.2.3
# contourpy                    1.3.2
# cycler                       0.12.1
# debugpy                      1.8.17
# decorator                    5.2.1
# exceptiongroup               1.3.1
# executing                    2.2.1
# flatbuffers                  25.9.23
# fonttools                    4.61.0
# gast                         0.7.0
# google-auth                  2.41.1
# google-auth-oauthlib         1.2.3
# google-pasta                 0.2.0
# grpcio                       1.76.0
# h5py                         3.15.1
# idna                         3.11
# imutils                      0.5.4
# ipykernel                    7.1.0
# ipython                      8.37.0
# jedi                         0.19.2
# joblib                       1.5.2
# jupyter_client               8.6.3
# jupyter_core                 5.9.1
# keras                        2.15.0
# kiwisolver                   1.4.9
# libclang                     18.1.1
# Markdown                     3.10
# MarkupSafe                   3.0.3
# matplotlib                   3.10.7
# matplotlib-inline            0.2.1
# ml-dtypes                    0.2.0
# nest-asyncio                 1.6.0
# numpy                        1.26.4
# nvidia-cublas-cu12           12.2.5.6
# nvidia-cuda-cupti-cu12       12.2.142
# nvidia-cuda-nvcc-cu12        12.2.140
# nvidia-cuda-nvrtc-cu12       12.2.140
# nvidia-cuda-runtime-cu12     12.2.140
# nvidia-cudnn-cu12            8.9.4.25
# nvidia-cufft-cu12            11.0.8.103
# nvidia-curand-cu12           10.3.3.141
# nvidia-cusolver-cu12         11.5.2.141
# nvidia-cusparse-cu12         12.1.2.141
# nvidia-nccl-cu12             2.16.5
# nvidia-nvjitlink-cu12        12.2.140
# oauthlib                     3.3.1
# opencv-python                4.11.0.86
# opt_einsum                   3.4.0
# packaging                    25.0
# pandas                       2.3.3
# parso                        0.8.5
# patsy                        1.0.2
# pexpect                      4.9.0
# pillow                       12.0.0
# pip                          22.0.2
# platformdirs                 4.5.0
# prompt_toolkit               3.0.52
# protobuf                     4.25.8
# psutil                       7.1.3
# ptyprocess                   0.7.0
# pure_eval                    0.2.3
# pyasn1                       0.6.1
# pyasn1_modules               0.4.2
# Pygments                     2.19.2
# pyparsing                    3.2.5
# python-dateutil              2.9.0.post0
# pytz                         2025.2
# pyzmq                        27.1.0
# requests                     2.32.5
# requests-oauthlib            2.0.0
# rsa                          4.9.1
# scikit-learn                 1.7.2
# scipy                        1.15.3
# seaborn                      0.13.2
# setuptools                   59.6.0
# six                          1.17.0
# stack-data                   0.6.3
# statsmodels                  0.14.5
# tensorboard                  2.15.2
# tensorboard-data-server      0.7.2
# tensorflow                   2.15.0.post1
# tensorflow-estimator         2.15.0
# tensorflow-io-gcs-filesystem 0.37.1
# termcolor                    3.2.0
# threadpoolctl                3.6.0
# tornado                      6.5.2
# traitlets                    5.14.3
# typing_extensions            4.15.0
# tzdata                       2025.2
# urllib3                      2.5.0
# wcwidth                      0.2.14
# Werkzeug                     3.1.4
# wheel                        0.45.1
# wrapt                        1.14.2
# xgboost                      3.1.2

# %%
import tensorflow as tf
# Out:
# 2025-12-10 14:06:44.813028: I tensorflow/core/util/port.cc:113] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2025-12-10 14:06:45.211867: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2025-12-10 14:06:45.212110: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2025-12-10 14:06:45.280519: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2025-12-10 14:06:45.417343: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2025-12-10 14:06:59.605945: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT

# %%
tf.test.is_gpu_available()
# Out:
# WARNING:tensorflow:From /tmp/ipykernel_16821/337460670.py:1: is_gpu_available (from tensorflow.python.framework.test_util) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.config.list_physical_devices('GPU')` instead.
# 2025-12-10 14:07:29.268737: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:887] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2025-12-10 14:07:29.767583: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:887] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2025-12-10 14:07:29.767623: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:887] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2025-12-10 14:07:29.767628: W tensorflow/core/common_runtime/gpu/gpu_device.cc:2348] TensorFlow was not built with CUDA kernel binaries compatible with compute capability 12.0. CUDA kernels will be jit-compiled from PTX, which could take 30 minutes or longer.
# 2025-12-10 14:07:29.913297: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:887] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2025-12-10 14:07:29.913346: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:887] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2025-12-10 14:07:29.913352: I tensorflow/core/common_runtime/gpu/gpu_device.cc:2022] Could not identify NUMA node of platform GPU id 0, defaulting to 0.  Your kernel may not have been built with NUMA support.
# 2025-12-10 14:07:29.913375: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:887] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2025-12-10 14:07:29.913847: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1929] Created device /device:GPU:0 with 13067 MB memory:  -> device: 0, name: NVIDIA GeForce RTX 5080, pci bus id: 0000:01:00.0, compute capability: 12.0
# True

# %%
tf.config.list_physical_devices('GPU')
# Out:
# 2025-12-10 14:07:32.962041: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:887] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2025-12-10 14:07:32.962107: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:887] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2025-12-10 14:07:32.962122: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:887] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2025-12-10 14:07:32.962126: W tensorflow/core/common_runtime/gpu/gpu_device.cc:2348] TensorFlow was not built with CUDA kernel binaries compatible with compute capability 12.0. CUDA kernels will be jit-compiled from PTX, which could take 30 minutes or longer.
# [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]

# %%
len(tf.config.list_physical_devices('GPU'))
# Out:
# 1

# %%
tf.test.is_built_with_cuda()
# Out:
# True

# %%
# from google.colab import drive
# drive.mount('/content/drive/')
# Out:
# Mounted at /content/drive/

# %%
# Importing Libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import datetime
import tensorflow
from sklearn.metrics import r2_score
from sklearn.metrics import mean_absolute_error
from sklearn.metrics import mean_absolute_percentage_error
from statsmodels.tsa.stattools import adfuller
from sklearn.preprocessing import MinMaxScaler
from tensorflow import keras
from keras import callbacks
from tensorflow.keras import Sequential
from tensorflow.keras.layers import Conv2D, Flatten, Dense, LSTM, Dropout, GRU, Bidirectional
from tensorflow.keras.layers import Activation
from tensorflow.keras.optimizers import SGD
import math
from sklearn.metrics import mean_squared_error
from tensorflow.keras import backend as K
from sklearn.preprocessing import LabelBinarizer
from sklearn.model_selection import train_test_split
import random
import cv2
import os
from imutils import paths
from sklearn.utils import shuffle
from sklearn.metrics import accuracy_score
from sklearn.preprocessing import LabelEncoder
from mpl_toolkits.mplot3d import Axes3D
from sklearn.metrics import classification_report
from sklearn.ensemble import RandomForestClassifier
from xgboost import XGBClassifier

# %%
#df = pd.read_csv('/content/drive/MyDrive/Thesis/Dataset/RAW/dataset_5secondWindow.csv')
df = pd.read_csv('Datasets/dataset_5secondWindow.csv')

# %%
df
# Out:
#          id  time  activityrecognition#0  activityrecognition#1  \
# 0     16170    78                    NaN                    100
# 1     15871   145                    NaN                    100
# 2     16811   150                    NaN                    100
# 3     15831   105                    NaN                     77
# 4       876    77                    NaN                    100
# ...     ...   ...                    ...                    ...
# 5888  14125     4                    NaN                    100
# 5889  19582    32                    NaN                     10
# 5890  16178    86                    NaN                    100
# 5891  10973   199                    NaN                    100
# 5892   8278    55                    NaN                    100
#
#       android.sensor.accelerometer#mean  android.sensor.accelerometer#min  \
# 0                              9.811476                          9.758895
# 1                              9.939207                          7.707437
# 2                              9.827178                          9.804817
# 3                              9.673039                          7.659674
# 4                              9.993466                          8.965621
# ...                                 ...                               ...
# 5888                          10.066610                          4.564648
# 5889                           9.964271                          8.768007
# 5890                           9.812893                          9.772881
# 5891                           9.831144                          9.807347
# 5892                          11.051009                          5.203285
#
#       android.sensor.accelerometer#max  android.sensor.accelerometer#std  \
# 0                             9.849411                          0.014626
# 1                            17.146631                          1.775944
# 2                             9.849262                          0.011199
# 3                            12.304298                          0.862553
# 4                            10.891645                          0.504117
# ...                                ...                               ...
# 5888                         13.414389                          3.373972
# 5889                         11.454213                          0.665529
# 5890                          9.862587                          0.017633
# 5891                          9.874450                          0.013485
# 5892                         19.921068                          4.745098
#
#       android.sensor.game_rotation_vector#mean  \
# 0                                     0.029340
# 1                                     0.999925
# 2                                     0.665215
# 3                                     0.996221
# 4                                     0.563792
# ...                                        ...
# 5888                                  0.986319
# 5889                                  0.648602
# 5890                                  0.024392
# 5891                                  0.481212
# 5892                                  0.919815
#
#       android.sensor.game_rotation_vector#min  ...  sound#mean  sound#min  \
# 0                                    0.029014  ...         NaN        NaN
# 1                                    0.999903  ...   89.200210  89.065143
# 2                                    0.665213  ...         NaN        NaN
# 3                                    0.993781  ...   87.470377  87.470377
# 4                                    0.521799  ...   89.770732  89.770732
# ...                                       ...  ...         ...        ...
# 5888                                 0.974523  ...         NaN        NaN
# 5889                                 0.648343  ...         NaN        NaN
# 5890                                 0.024081  ...         NaN        NaN
# 5891                                 0.481209  ...         NaN        NaN
# 5892                                 0.892571  ...   89.712441  89.712441
#
#       sound#max  sound#std  speed#mean  speed#min  speed#max  speed#std  \
# 0           NaN        NaN    0.000000   0.000000   0.000000   0.000000
# 1     89.335277   0.191013   16.539349  16.539349  16.539349   0.628595
# 2           NaN        NaN    0.000000   0.000000   0.000000   0.000000
# 3     87.470377   2.284186   17.739895  17.739895  17.739895   0.628595
# 4     89.770732   0.006389    9.000000   9.000000   9.000000        NaN
# ...         ...        ...         ...        ...        ...        ...
# 5888        NaN        NaN         NaN        NaN        NaN        NaN
# 5889        NaN        NaN   31.960054  31.960054  31.960054        NaN
# 5890        NaN        NaN    0.000000   0.000000   0.000000   0.000000
# 5891        NaN        NaN    1.090415   1.090415   1.090415        NaN
# 5892  89.712441   0.006400    0.750000   0.750000   0.750000        NaN
#
#        target  user
# 0       Still   U12
# 1         Car   U12
# 2       Still   U12
# 3         Car   U12
# 4         Car    U1
# ...       ...   ...
# 5888  Walking    U2
# 5889    Train    U3
# 5890    Still   U12
# 5891    Still   U10
# 5892  Walking    U1
#
# [5893 rows x 70 columns]

# %%
column_lst = list(df.columns)
mostly_null = []
partially_null = []
no_null = []

# %%
for i in column_lst:
    percentage = (df[i].isnull().sum()*100)/5893
    if percentage >= 60:
        mostly_null.append(i)
    elif df[i].isnull().sum() > 0:
        partially_null.append(i)
    elif df[i].isnull().sum() == 0:
        no_null.append(i)

    print('Feature Name:',i)
    print("Number of missing values: ",df[i].isnull().sum(),"out of 5893")
    print("Missing percentage:"+str(percentage)+"%")
    print()
# Out:
# Feature Name: id
# Number of missing values:  0 out of 5893
# Missing percentage:0.0%
#
# Feature Name: time
# Number of missing values:  0 out of 5893
# Missing percentage:0.0%
#
# Feature Name: activityrecognition#0
# Number of missing values:  5893 out of 5893
# Missing percentage:100.0%
#
# Feature Name: activityrecognition#1
# Number of missing values:  0 out of 5893
# Missing percentage:0.0%
#
# Feature Name: android.sensor.accelerometer#mean
# Number of missing values:  0 out of 5893
# Missing percentage:0.0%
#
# Feature Name: android.sensor.accelerometer#min
# Number of missing values:  0 out of 5893
# Missing percentage:0.0%
#
# Feature Name: android.sensor.accelerometer#max
# Number of missing values:  0 out of 5893
# Missing percentage:0.0%
#
# Feature Name: android.sensor.accelerometer#std
# Number of missing values:  0 out of 5893
# Missing percentage:0.0%
#
# Feature Name: android.sensor.game_rotation_vector#mean
# Number of missing values:  799 out of 5893
# Missing percentage:13.558459188868149%
#
# Feature Name: android.sensor.game_rotation_vector#min
# Number of missing values:  799 out of 5893
# Missing percentage:13.558459188868149%
#
# Feature Name: android.sensor.game_rotation_vector#max
# Number of missing values:  799 out of 5893
# Missing percentage:13.558459188868149%
#
# Feature Name: android.sensor.game_rotation_vector#std
# Number of missing values:  800 out of 5893
# Missing percentage:13.575428474461225%
#
# Feature Name: android.sensor.gravity#mean
# Number of missing values:  497 out of 5893
# Missing percentage:8.433734939759036%
#
# Feature Name: android.sensor.gravity#min
# Number of missing values:  497 out of 5893
# Missing percentage:8.433734939759036%
#
# Feature Name: android.sensor.gravity#max
# Number of missing values:  497 out of 5893
# Missing percentage:8.433734939759036%
#
# Feature Name: android.sensor.gravity#std
# Number of missing values:  537 out of 5893
# Missing percentage:9.112506363482098%
#
# Feature Name: android.sensor.gyroscope#mean
# Number of missing values:  720 out of 5893
# Missing percentage:12.217885627015102%
#
# Feature Name: android.sensor.gyroscope#min
# Number of missing values:  720 out of 5893
# Missing percentage:12.217885627015102%
#
# Feature Name: android.sensor.gyroscope#max
# Number of missing values:  720 out of 5893
# Missing percentage:12.217885627015102%
#
# Feature Name: android.sensor.gyroscope#std
# Number of missing values:  721 out of 5893
# Missing percentage:12.23485491260818%
#
# Feature Name: android.sensor.gyroscope_uncalibrated#mean
# Number of missing values:  799 out of 5893
# Missing percentage:13.558459188868149%
#
# Feature Name: android.sensor.gyroscope_uncalibrated#min
# Number of missing values:  799 out of 5893
# Missing percentage:13.558459188868149%
#
# Feature Name: android.sensor.gyroscope_uncalibrated#max
# Number of missing values:  799 out of 5893
# Missing percentage:13.558459188868149%
#
# Feature Name: android.sensor.gyroscope_uncalibrated#std
# Number of missing values:  799 out of 5893
# Missing percentage:13.558459188868149%
#
# Feature Name: android.sensor.light#mean
# Number of missing values:  1512 out of 5893
# Missing percentage:25.657559816731716%
#
# Feature Name: android.sensor.light#min
# Number of missing values:  1512 out of 5893
# Missing percentage:25.657559816731716%
#
# Feature Name: android.sensor.light#max
# Number of missing values:  1512 out of 5893
# Missing percentage:25.657559816731716%
#
# Feature Name: android.sensor.light#std
# Number of missing values:  3769 out of 5893
# Missing percentage:63.957237400305445%
#
# Feature Name: android.sensor.linear_acceleration#mean
# Number of missing values:  494 out of 5893
# Missing percentage:8.382827082979807%
#
# Feature Name: android.sensor.linear_acceleration#min
# Number of missing values:  494 out of 5893
# Missing percentage:8.382827082979807%
#
# Feature Name: android.sensor.linear_acceleration#max
# Number of missing values:  494 out of 5893
# Missing percentage:8.382827082979807%
#
# Feature Name: android.sensor.linear_acceleration#std
# Number of missing values:  523 out of 5893
# Missing percentage:8.874936365179027%
#
# Feature Name: android.sensor.magnetic_field#mean
# Number of missing values:  493 out of 5893
# Missing percentage:8.36585779738673%
#
# Feature Name: android.sensor.magnetic_field#min
# Number of missing values:  493 out of 5893
# Missing percentage:8.36585779738673%
#
# Feature Name: android.sensor.magnetic_field#max
# Number of missing values:  493 out of 5893
# Missing percentage:8.36585779738673%
#
# Feature Name: android.sensor.magnetic_field#std
# Number of missing values:  510 out of 5893
# Missing percentage:8.654335652469031%
#
# Feature Name: android.sensor.magnetic_field_uncalibrated#mean
# Number of missing values:  799 out of 5893
# Missing percentage:13.558459188868149%
#
# Feature Name: android.sensor.magnetic_field_uncalibrated#min
# Number of missing values:  799 out of 5893
# Missing percentage:13.558459188868149%
#
# Feature Name: android.sensor.magnetic_field_uncalibrated#max
# Number of missing values:  799 out of 5893
# Missing percentage:13.558459188868149%
#
# Feature Name: android.sensor.magnetic_field_uncalibrated#std
# Number of missing values:  806 out of 5893
# Missing percentage:13.677244188019685%
#
# Feature Name: android.sensor.orientation#mean
# Number of missing values:  497 out of 5893
# Missing percentage:8.433734939759036%
#
# Feature Name: android.sensor.orientation#min
# Number of missing values:  497 out of 5893
# Missing percentage:8.433734939759036%
#
# Feature Name: android.sensor.orientation#max
# Number of missing values:  497 out of 5893
# Missing percentage:8.433734939759036%
#
# Feature Name: android.sensor.orientation#std
# Number of missing values:  520 out of 5893
# Missing percentage:8.824028508399797%
#
# Feature Name: android.sensor.pressure#mean
# Number of missing values:  3975 out of 5893
# Missing percentage:67.45291023247921%
#
# Feature Name: android.sensor.pressure#min
# Number of missing values:  3975 out of 5893
# Missing percentage:67.45291023247921%
#
# Feature Name: android.sensor.pressure#max
# Number of missing values:  3975 out of 5893
# Missing percentage:67.45291023247921%
#
# Feature Name: android.sensor.pressure#std
# Number of missing values:  4765 out of 5893
# Missing percentage:80.85864585100967%
#
# Feature Name: android.sensor.proximity#mean
# Number of missing values:  4774 out of 5893
# Missing percentage:81.01136942134737%
#
# Feature Name: android.sensor.proximity#min
# Number of missing values:  4774 out of 5893
# Missing percentage:81.01136942134737%
#
# Feature Name: android.sensor.proximity#max
# Number of missing values:  4774 out of 5893
# Missing percentage:81.01136942134737%
#
# Feature Name: android.sensor.proximity#std
# Number of missing values:  5610 out of 5893
# Missing percentage:95.19769217715934%
#
# Feature Name: android.sensor.rotation_vector#mean
# Number of missing values:  721 out of 5893
# Missing percentage:12.23485491260818%
#
# Feature Name: android.sensor.rotation_vector#min
# Number of missing values:  721 out of 5893
# Missing percentage:12.23485491260818%
#
# Feature Name: android.sensor.rotation_vector#max
# Number of missing values:  721 out of 5893
# Missing percentage:12.23485491260818%
#
# Feature Name: android.sensor.rotation_vector#std
# Number of missing values:  730 out of 5893
# Missing percentage:12.387578482945868%
#
# Feature Name: android.sensor.step_counter#mean
# Number of missing values:  4406 out of 5893
# Missing percentage:74.7666723230952%
#
# Feature Name: android.sensor.step_counter#min
# Number of missing values:  4406 out of 5893
# Missing percentage:74.7666723230952%
#
# Feature Name: android.sensor.step_counter#max
# Number of missing values:  4406 out of 5893
# Missing percentage:74.7666723230952%
#
# Feature Name: android.sensor.step_counter#std
# Number of missing values:  5661 out of 5893
# Missing percentage:96.06312574240624%
#
# Feature Name: sound#mean
# Number of missing values:  994 out of 5893
# Missing percentage:16.867469879518072%
#
# Feature Name: sound#min
# Number of missing values:  994 out of 5893
# Missing percentage:16.867469879518072%
#
# Feature Name: sound#max
# Number of missing values:  994 out of 5893
# Missing percentage:16.867469879518072%
#
# Feature Name: sound#std
# Number of missing values:  1831 out of 5893
# Missing percentage:31.07076192092313%
#
# Feature Name: speed#mean
# Number of missing values:  2373 out of 5893
# Missing percentage:40.26811471237061%
#
# Feature Name: speed#min
# Number of missing values:  2373 out of 5893
# Missing percentage:40.26811471237061%
#
# Feature Name: speed#max
# Number of missing values:  2373 out of 5893
# Missing percentage:40.26811471237061%
#
# Feature Name: speed#std
# Number of missing values:  4575 out of 5893
# Missing percentage:77.63448158832513%
#
# Feature Name: target
# Number of missing values:  0 out of 5893
# Missing percentage:0.0%
#
# Feature Name: user
# Number of missing values:  0 out of 5893
# Missing percentage:0.0%

# %%
if len(mostly_null)+len(partially_null)+len(no_null) == len(column_lst):
    print("True")
else:
    print("False")
# Out:
# True

# %%
mostly_null
# Out:
# ['activityrecognition#0',
#  'android.sensor.light#std',
#  'android.sensor.pressure#mean',
#  'android.sensor.pressure#min',
#  'android.sensor.pressure#max',
#  'android.sensor.pressure#std',
#  'android.sensor.proximity#mean',
#  'android.sensor.proximity#min',
#  'android.sensor.proximity#max',
#  'android.sensor.proximity#std',
#  'android.sensor.step_counter#mean',
#  'android.sensor.step_counter#min',
#  'android.sensor.step_counter#max',
#  'android.sensor.step_counter#std',
#  'speed#std']

# %%
for i in mostly_null:
    df = df.drop([i], axis = 1)

# %%
df = df.drop(['id'], axis = 1)

# %%
partially_null
# Out:
# ['android.sensor.game_rotation_vector#mean',
#  'android.sensor.game_rotation_vector#min',
#  'android.sensor.game_rotation_vector#max',
#  'android.sensor.game_rotation_vector#std',
#  'android.sensor.gravity#mean',
#  'android.sensor.gravity#min',
#  'android.sensor.gravity#max',
#  'android.sensor.gravity#std',
#  'android.sensor.gyroscope#mean',
#  'android.sensor.gyroscope#min',
#  'android.sensor.gyroscope#max',
#  'android.sensor.gyroscope#std',
#  'android.sensor.gyroscope_uncalibrated#mean',
#  'android.sensor.gyroscope_uncalibrated#min',
#  'android.sensor.gyroscope_uncalibrated#max',
#  'android.sensor.gyroscope_uncalibrated#std',
#  'android.sensor.light#mean',
#  'android.sensor.light#min',
#  'android.sensor.light#max',
#  'android.sensor.linear_acceleration#mean',
#  'android.sensor.linear_acceleration#min',
#  'android.sensor.linear_acceleration#max',
#  'android.sensor.linear_acceleration#std',
#  'android.sensor.magnetic_field#mean',
#  'android.sensor.magnetic_field#min',
#  'android.sensor.magnetic_field#max',
#  'android.sensor.magnetic_field#std',
#  'android.sensor.magnetic_field_uncalibrated#mean',
#  'android.sensor.magnetic_field_uncalibrated#min',
#  'android.sensor.magnetic_field_uncalibrated#max',
#  'android.sensor.magnetic_field_uncalibrated#std',
#  'android.sensor.orientation#mean',
#  'android.sensor.orientation#min',
#  'android.sensor.orientation#max',
#  'android.sensor.orientation#std',
#  'android.sensor.rotation_vector#mean',
#  'android.sensor.rotation_vector#min',
#  'android.sensor.rotation_vector#max',
#  'android.sensor.rotation_vector#std',
#  'sound#mean',
#  'sound#min',
#  'sound#max',
#  'sound#std',
#  'speed#mean',
#  'speed#min',
#  'speed#max']

# %%
for i in partially_null:
    print("Partially Null Feature Name:",i)
    print("Number of unique values: ",len(df[i].unique()),"and Number of missing values: ",df[i].isnull().sum())
    print()
# Out:
# Partially Null Feature Name: android.sensor.game_rotation_vector#mean
# Number of unique values:  4922 and Number of missing values:  799
#
# Partially Null Feature Name: android.sensor.game_rotation_vector#min
# Number of unique values:  4913 and Number of missing values:  799
#
# Partially Null Feature Name: android.sensor.game_rotation_vector#max
# Number of unique values:  4914 and Number of missing values:  799
#
# Partially Null Feature Name: android.sensor.game_rotation_vector#std
# Number of unique values:  4472 and Number of missing values:  800
#
# Partially Null Feature Name: android.sensor.gravity#mean
# Number of unique values:  2367 and Number of missing values:  497
#
# Partially Null Feature Name: android.sensor.gravity#min
# Number of unique values:  2739 and Number of missing values:  497
#
# Partially Null Feature Name: android.sensor.gravity#max
# Number of unique values:  2736 and Number of missing values:  497
#
# Partially Null Feature Name: android.sensor.gravity#std
# Number of unique values:  1344 and Number of missing values:  537
#
# Partially Null Feature Name: android.sensor.gyroscope#mean
# Number of unique values:  5015 and Number of missing values:  720
#
# Partially Null Feature Name: android.sensor.gyroscope#min
# Number of unique values:  4113 and Number of missing values:  720
#
# Partially Null Feature Name: android.sensor.gyroscope#max
# Number of unique values:  4688 and Number of missing values:  720
#
# Partially Null Feature Name: android.sensor.gyroscope#std
# Number of unique values:  4924 and Number of missing values:  721
#
# Partially Null Feature Name: android.sensor.gyroscope_uncalibrated#mean
# Number of unique values:  5000 and Number of missing values:  799
#
# Partially Null Feature Name: android.sensor.gyroscope_uncalibrated#min
# Number of unique values:  4185 and Number of missing values:  799
#
# Partially Null Feature Name: android.sensor.gyroscope_uncalibrated#max
# Number of unique values:  4628 and Number of missing values:  799
#
# Partially Null Feature Name: android.sensor.gyroscope_uncalibrated#std
# Number of unique values:  4901 and Number of missing values:  799
#
# Partially Null Feature Name: android.sensor.light#mean
# Number of unique values:  569 and Number of missing values:  1512
#
# Partially Null Feature Name: android.sensor.light#min
# Number of unique values:  357 and Number of missing values:  1512
#
# Partially Null Feature Name: android.sensor.light#max
# Number of unique values:  369 and Number of missing values:  1512
#
# Partially Null Feature Name: android.sensor.linear_acceleration#mean
# Number of unique values:  4973 and Number of missing values:  494
#
# Partially Null Feature Name: android.sensor.linear_acceleration#min
# Number of unique values:  4963 and Number of missing values:  494
#
# Partially Null Feature Name: android.sensor.linear_acceleration#max
# Number of unique values:  4968 and Number of missing values:  494
#
# Partially Null Feature Name: android.sensor.linear_acceleration#std
# Number of unique values:  4248 and Number of missing values:  523
#
# Partially Null Feature Name: android.sensor.magnetic_field#mean
# Number of unique values:  5144 and Number of missing values:  493
#
# Partially Null Feature Name: android.sensor.magnetic_field#min
# Number of unique values:  5107 and Number of missing values:  493
#
# Partially Null Feature Name: android.sensor.magnetic_field#max
# Number of unique values:  5115 and Number of missing values:  493
#
# Partially Null Feature Name: android.sensor.magnetic_field#std
# Number of unique values:  4723 and Number of missing values:  510
#
# Partially Null Feature Name: android.sensor.magnetic_field_uncalibrated#mean
# Number of unique values:  4752 and Number of missing values:  799
#
# Partially Null Feature Name: android.sensor.magnetic_field_uncalibrated#min
# Number of unique values:  4708 and Number of missing values:  799
#
# Partially Null Feature Name: android.sensor.magnetic_field_uncalibrated#max
# Number of unique values:  4709 and Number of missing values:  799
#
# Partially Null Feature Name: android.sensor.magnetic_field_uncalibrated#std
# Number of unique values:  4024 and Number of missing values:  806
#
# Partially Null Feature Name: android.sensor.orientation#mean
# Number of unique values:  5119 and Number of missing values:  497
#
# Partially Null Feature Name: android.sensor.orientation#min
# Number of unique values:  5115 and Number of missing values:  497
#
# Partially Null Feature Name: android.sensor.orientation#max
# Number of unique values:  5115 and Number of missing values:  497
#
# Partially Null Feature Name: android.sensor.orientation#std
# Number of unique values:  4681 and Number of missing values:  520
#
# Partially Null Feature Name: android.sensor.rotation_vector#mean
# Number of unique values:  5003 and Number of missing values:  721
#
# Partially Null Feature Name: android.sensor.rotation_vector#min
# Number of unique values:  4984 and Number of missing values:  721
#
# Partially Null Feature Name: android.sensor.rotation_vector#max
# Number of unique values:  4988 and Number of missing values:  721
#
# Partially Null Feature Name: android.sensor.rotation_vector#std
# Number of unique values:  4594 and Number of missing values:  730
#
# Partially Null Feature Name: sound#mean
# Number of unique values:  2445 and Number of missing values:  994
#
# Partially Null Feature Name: sound#min
# Number of unique values:  2307 and Number of missing values:  994
#
# Partially Null Feature Name: sound#max
# Number of unique values:  2307 and Number of missing values:  994
#
# Partially Null Feature Name: sound#std
# Number of unique values:  869 and Number of missing values:  1831
#
# Partially Null Feature Name: speed#mean
# Number of unique values:  647 and Number of missing values:  2373
#
# Partially Null Feature Name: speed#min
# Number of unique values:  634 and Number of missing values:  2373
#
# Partially Null Feature Name: speed#max
# Number of unique values:  643 and Number of missing values:  2373

# %%
for i in partially_null:
    df[i] = df[i].fillna(0)

# %%
newcolumns = list(df.columns)

# %%
for i in newcolumns:
    
    print('Feature Name:',i)
    print("Number of missing values: ",df[i].isnull().sum(),"out of 5893")
    print("Missing percentage:"+str(percentage)+"%")
    print()
# Out:
# Feature Name: time
# Number of missing values:  0 out of 5893
# Missing percentage:0.0%
#
# Feature Name: activityrecognition#1
# Number of missing values:  0 out of 5893
# Missing percentage:0.0%
#
# Feature Name: android.sensor.accelerometer#mean
# Number of missing values:  0 out of 5893
# Missing percentage:0.0%
#
# Feature Name: android.sensor.accelerometer#min
# Number of missing values:  0 out of 5893
# Missing percentage:0.0%
#
# Feature Name: android.sensor.accelerometer#max
# Number of missing values:  0 out of 5893
# Missing percentage:0.0%
#
# Feature Name: android.sensor.accelerometer#std
# Number of missing values:  0 out of 5893
# Missing percentage:0.0%
#
# Feature Name: android.sensor.game_rotation_vector#mean
# Number of missing values:  0 out of 5893
# Missing percentage:0.0%
#
# Feature Name: android.sensor.game_rotation_vector#min
# Number of missing values:  0 out of 5893
# Missing percentage:0.0%
#
# Feature Name: android.sensor.game_rotation_vector#max
# Number of missing values:  0 out of 5893
# Missing percentage:0.0%
#
# Feature Name: android.sensor.game_rotation_vector#std
# Number of missing values:  0 out of 5893
# Missing percentage:0.0%
#
# Feature Name: android.sensor.gravity#mean
# Number of missing values:  0 out of 5893
# Missing percentage:0.0%
#
# Feature Name: android.sensor.gravity#min
# Number of missing values:  0 out of 5893
# Missing percentage:0.0%
#
# Feature Name: android.sensor.gravity#max
# Number of missing values:  0 out of 5893
# Missing percentage:0.0%
#
# Feature Name: android.sensor.gravity#std
# Number of missing values:  0 out of 5893
# Missing percentage:0.0%
#
# Feature Name: android.sensor.gyroscope#mean
# Number of missing values:  0 out of 5893
# Missing percentage:0.0%
#
# Feature Name: android.sensor.gyroscope#min
# Number of missing values:  0 out of 5893
# Missing percentage:0.0%
#
# Feature Name: android.sensor.gyroscope#max
# Number of missing values:  0 out of 5893
# Missing percentage:0.0%
#
# Feature Name: android.sensor.gyroscope#std
# Number of missing values:  0 out of 5893
# Missing percentage:0.0%
#
# Feature Name: android.sensor.gyroscope_uncalibrated#mean
# Number of missing values:  0 out of 5893
# Missing percentage:0.0%
#
# Feature Name: android.sensor.gyroscope_uncalibrated#min
# Number of missing values:  0 out of 5893
# Missing percentage:0.0%
#
# Feature Name: android.sensor.gyroscope_uncalibrated#max
# Number of missing values:  0 out of 5893
# Missing percentage:0.0%
#
# Feature Name: android.sensor.gyroscope_uncalibrated#std
# Number of missing values:  0 out of 5893
# Missing percentage:0.0%
#
# Feature Name: android.sensor.light#mean
# Number of missing values:  0 out of 5893
# Missing percentage:0.0%
#
# Feature Name: android.sensor.light#min
# Number of missing values:  0 out of 5893
# Missing percentage:0.0%
#
# Feature Name: android.sensor.light#max
# Number of missing values:  0 out of 5893
# Missing percentage:0.0%
#
# Feature Name: android.sensor.linear_acceleration#mean
# Number of missing values:  0 out of 5893
# Missing percentage:0.0%
#
# Feature Name: android.sensor.linear_acceleration#min
# Number of missing values:  0 out of 5893
# Missing percentage:0.0%
#
# Feature Name: android.sensor.linear_acceleration#max
# Number of missing values:  0 out of 5893
# Missing percentage:0.0%
#
# Feature Name: android.sensor.linear_acceleration#std
# Number of missing values:  0 out of 5893
# Missing percentage:0.0%
#
# Feature Name: android.sensor.magnetic_field#mean
# Number of missing values:  0 out of 5893
# Missing percentage:0.0%
#
# Feature Name: android.sensor.magnetic_field#min
# Number of missing values:  0 out of 5893
# Missing percentage:0.0%
#
# Feature Name: android.sensor.magnetic_field#max
# Number of missing values:  0 out of 5893
# Missing percentage:0.0%
#
# Feature Name: android.sensor.magnetic_field#std
# Number of missing values:  0 out of 5893
# Missing percentage:0.0%
#
# Feature Name: android.sensor.magnetic_field_uncalibrated#mean
# Number of missing values:  0 out of 5893
# Missing percentage:0.0%
#
# Feature Name: android.sensor.magnetic_field_uncalibrated#min
# Number of missing values:  0 out of 5893
# Missing percentage:0.0%
#
# Feature Name: android.sensor.magnetic_field_uncalibrated#max
# Number of missing values:  0 out of 5893
# Missing percentage:0.0%
#
# Feature Name: android.sensor.magnetic_field_uncalibrated#std
# Number of missing values:  0 out of 5893
# Missing percentage:0.0%
#
# Feature Name: android.sensor.orientation#mean
# Number of missing values:  0 out of 5893
# Missing percentage:0.0%
#
# Feature Name: android.sensor.orientation#min
# Number of missing values:  0 out of 5893
# Missing percentage:0.0%
#
# Feature Name: android.sensor.orientation#max
# Number of missing values:  0 out of 5893
# Missing percentage:0.0%
#
# Feature Name: android.sensor.orientation#std
# Number of missing values:  0 out of 5893
# Missing percentage:0.0%
#
# Feature Name: android.sensor.rotation_vector#mean
# Number of missing values:  0 out of 5893
# Missing percentage:0.0%
#
# Feature Name: android.sensor.rotation_vector#min
# Number of missing values:  0 out of 5893
# Missing percentage:0.0%
#
# Feature Name: android.sensor.rotation_vector#max
# Number of missing values:  0 out of 5893
# Missing percentage:0.0%
#
# Feature Name: android.sensor.rotation_vector#std
# Number of missing values:  0 out of 5893
# Missing percentage:0.0%
#
# Feature Name: sound#mean
# Number of missing values:  0 out of 5893
# Missing percentage:0.0%
#
# Feature Name: sound#min
# Number of missing values:  0 out of 5893
# Missing percentage:0.0%
#
# Feature Name: sound#max
# Number of missing values:  0 out of 5893
# Missing percentage:0.0%
#
# Feature Name: sound#std
# Number of missing values:  0 out of 5893
# Missing percentage:0.0%
#
# Feature Name: speed#mean
# Number of missing values:  0 out of 5893
# Missing percentage:0.0%
#
# Feature Name: speed#min
# Number of missing values:  0 out of 5893
# Missing percentage:0.0%
#
# Feature Name: speed#max
# Number of missing values:  0 out of 5893
# Missing percentage:0.0%
#
# Feature Name: target
# Number of missing values:  0 out of 5893
# Missing percentage:0.0%
#
# Feature Name: user
# Number of missing values:  0 out of 5893
# Missing percentage:0.0%

# %%
df
# Out:
#       time  activityrecognition#1  android.sensor.accelerometer#mean  \
# 0       78                    100                           9.811476
# 1      145                    100                           9.939207
# 2      150                    100                           9.827178
# 3      105                     77                           9.673039
# 4       77                    100                           9.993466
# ...    ...                    ...                                ...
# 5888     4                    100                          10.066610
# 5889    32                     10                           9.964271
# 5890    86                    100                           9.812893
# 5891   199                    100                           9.831144
# 5892    55                    100                          11.051009
#
#       android.sensor.accelerometer#min  android.sensor.accelerometer#max  \
# 0                             9.758895                          9.849411
# 1                             7.707437                         17.146631
# 2                             9.804817                          9.849262
# 3                             7.659674                         12.304298
# 4                             8.965621                         10.891645
# ...                                ...                               ...
# 5888                          4.564648                         13.414389
# 5889                          8.768007                         11.454213
# 5890                          9.772881                          9.862587
# 5891                          9.807347                          9.874450
# 5892                          5.203285                         19.921068
#
#       android.sensor.accelerometer#std  \
# 0                             0.014626
# 1                             1.775944
# 2                             0.011199
# 3                             0.862553
# 4                             0.504117
# ...                                ...
# 5888                          3.373972
# 5889                          0.665529
# 5890                          0.017633
# 5891                          0.013485
# 5892                          4.745098
#
#       android.sensor.game_rotation_vector#mean  \
# 0                                     0.029340
# 1                                     0.999925
# 2                                     0.665215
# 3                                     0.996221
# 4                                     0.563792
# ...                                        ...
# 5888                                  0.986319
# 5889                                  0.648602
# 5890                                  0.024392
# 5891                                  0.481212
# 5892                                  0.919815
#
#       android.sensor.game_rotation_vector#min  \
# 0                                    0.029014
# 1                                    0.999903
# 2                                    0.665213
# 3                                    0.993781
# 4                                    0.521799
# ...                                       ...
# 5888                                 0.974523
# 5889                                 0.648343
# 5890                                 0.024081
# 5891                                 0.481209
# 5892                                 0.892571
#
#       android.sensor.game_rotation_vector#max  \
# 0                                    0.029526
# 1                                    0.999946
# 2                                    0.665218
# 3                                    0.998661
# 4                                    0.672664
# ...                                       ...
# 5888                                 0.992084
# 5889                                 0.648974
# 5890                                 0.024696
# 5891                                 0.481216
# 5892                                 0.944020
#
#       android.sensor.game_rotation_vector#std  ...  \
# 0                                    0.000119  ...
# 1                                    0.000030  ...
# 2                                    0.000004  ...
# 3                                    0.003451  ...
# 4                                    0.064792  ...
# ...                                       ...  ...
# 5888                                 0.007186  ...
# 5889                                 0.000331  ...
# 5890                                 0.000211  ...
# 5891                                 0.000002  ...
# 5892                                 0.019459  ...
#
#       android.sensor.rotation_vector#std  sound#mean  sound#min  sound#max  \
# 0                               0.002109    0.000000   0.000000   0.000000
# 1                               0.000026   89.200210  89.065143  89.335277
# 2                               0.011312    0.000000   0.000000   0.000000
# 3                               0.002788   87.470377  87.470377  87.470377
# 4                               0.025608   89.770732  89.770732  89.770732
# ...                                  ...         ...        ...        ...
# 5888                            0.008767    0.000000   0.000000   0.000000
# 5889                            0.018447    0.000000   0.000000   0.000000
# 5890                            0.002659    0.000000   0.000000   0.000000
# 5891                            0.000005    0.000000   0.000000   0.000000
# 5892                            0.003996   89.712441  89.712441  89.712441
#
#       sound#std  speed#mean  speed#min  speed#max   target  user
# 0      0.000000    0.000000   0.000000   0.000000    Still   U12
# 1      0.191013   16.539349  16.539349  16.539349      Car   U12
# 2      0.000000    0.000000   0.000000   0.000000    Still   U12
# 3      2.284186   17.739895  17.739895  17.739895      Car   U12
# 4      0.006389    9.000000   9.000000   9.000000      Car    U1
# ...         ...         ...        ...        ...      ...   ...
# 5888   0.000000    0.000000   0.000000   0.000000  Walking    U2
# 5889   0.000000   31.960054  31.960054  31.960054    Train    U3
# 5890   0.000000    0.000000   0.000000   0.000000    Still   U12
# 5891   0.000000    1.090415   1.090415   1.090415    Still   U10
# 5892   0.006400    0.750000   0.750000   0.750000  Walking    U1
#
# [5893 rows x 54 columns]

# %%
df['target'].unique()
# Out:
# array(['Still', 'Car', 'Train', 'Bus', 'Walking'], dtype=object)

# %%
df['target'] = df['target'].map({'Bus':0,'Car':1,'Still':2,'Train':3,'Walking':4})

# %%
df = df.drop(['user'], axis = 1)

# %%
df
# Out:
#       time  activityrecognition#1  android.sensor.accelerometer#mean  \
# 0       78                    100                           9.811476
# 1      145                    100                           9.939207
# 2      150                    100                           9.827178
# 3      105                     77                           9.673039
# 4       77                    100                           9.993466
# ...    ...                    ...                                ...
# 5888     4                    100                          10.066610
# 5889    32                     10                           9.964271
# 5890    86                    100                           9.812893
# 5891   199                    100                           9.831144
# 5892    55                    100                          11.051009
#
#       android.sensor.accelerometer#min  android.sensor.accelerometer#max  \
# 0                             9.758895                          9.849411
# 1                             7.707437                         17.146631
# 2                             9.804817                          9.849262
# 3                             7.659674                         12.304298
# 4                             8.965621                         10.891645
# ...                                ...                               ...
# 5888                          4.564648                         13.414389
# 5889                          8.768007                         11.454213
# 5890                          9.772881                          9.862587
# 5891                          9.807347                          9.874450
# 5892                          5.203285                         19.921068
#
#       android.sensor.accelerometer#std  \
# 0                             0.014626
# 1                             1.775944
# 2                             0.011199
# 3                             0.862553
# 4                             0.504117
# ...                                ...
# 5888                          3.373972
# 5889                          0.665529
# 5890                          0.017633
# 5891                          0.013485
# 5892                          4.745098
#
#       android.sensor.game_rotation_vector#mean  \
# 0                                     0.029340
# 1                                     0.999925
# 2                                     0.665215
# 3                                     0.996221
# 4                                     0.563792
# ...                                        ...
# 5888                                  0.986319
# 5889                                  0.648602
# 5890                                  0.024392
# 5891                                  0.481212
# 5892                                  0.919815
#
#       android.sensor.game_rotation_vector#min  \
# 0                                    0.029014
# 1                                    0.999903
# 2                                    0.665213
# 3                                    0.993781
# 4                                    0.521799
# ...                                       ...
# 5888                                 0.974523
# 5889                                 0.648343
# 5890                                 0.024081
# 5891                                 0.481209
# 5892                                 0.892571
#
#       android.sensor.game_rotation_vector#max  \
# 0                                    0.029526
# 1                                    0.999946
# 2                                    0.665218
# 3                                    0.998661
# 4                                    0.672664
# ...                                       ...
# 5888                                 0.992084
# 5889                                 0.648974
# 5890                                 0.024696
# 5891                                 0.481216
# 5892                                 0.944020
#
#       android.sensor.game_rotation_vector#std  ...  \
# 0                                    0.000119  ...
# 1                                    0.000030  ...
# 2                                    0.000004  ...
# 3                                    0.003451  ...
# 4                                    0.064792  ...
# ...                                       ...  ...
# 5888                                 0.007186  ...
# 5889                                 0.000331  ...
# 5890                                 0.000211  ...
# 5891                                 0.000002  ...
# 5892                                 0.019459  ...
#
#       android.sensor.rotation_vector#max  android.sensor.rotation_vector#std  \
# 0                               0.056351                            0.002109
# 1                               0.999999                            0.000026
# 2                               0.610456                            0.011312
# 3                               0.998112                            0.002788
# 4                               0.378193                            0.025608
# ...                                  ...                                 ...
# 5888                            0.941454                            0.008767
# 5889                            0.320622                            0.018447
# 5890                            0.059438                            0.002659
# 5891                            0.276354                            0.000005
# 5892                            0.996008                            0.003996
#
#       sound#mean  sound#min  sound#max  sound#std  speed#mean  speed#min  \
# 0       0.000000   0.000000   0.000000   0.000000    0.000000   0.000000
# 1      89.200210  89.065143  89.335277   0.191013   16.539349  16.539349
# 2       0.000000   0.000000   0.000000   0.000000    0.000000   0.000000
# 3      87.470377  87.470377  87.470377   2.284186   17.739895  17.739895
# 4      89.770732  89.770732  89.770732   0.006389    9.000000   9.000000
# ...          ...        ...        ...        ...         ...        ...
# 5888    0.000000   0.000000   0.000000   0.000000    0.000000   0.000000
# 5889    0.000000   0.000000   0.000000   0.000000   31.960054  31.960054
# 5890    0.000000   0.000000   0.000000   0.000000    0.000000   0.000000
# 5891    0.000000   0.000000   0.000000   0.000000    1.090415   1.090415
# 5892   89.712441  89.712441  89.712441   0.006400    0.750000   0.750000
#
#       speed#max  target
# 0      0.000000       2
# 1     16.539349       1
# 2      0.000000       2
# 3     17.739895       1
# 4      9.000000       1
# ...         ...     ...
# 5888   0.000000       4
# 5889  31.960054       3
# 5890   0.000000       2
# 5891   1.090415       2
# 5892   0.750000       4
#
# [5893 rows x 53 columns]

# %%
corr = df.corr()

plt.figure(figsize=(20,20))  
sns.heatmap(corr, annot = False, cmap = 'coolwarm')
# Out:
# <Axes: >

# %%
def correlation(dataset, threshold):
    col_corr = set()  # Set of all the names of correlated columns
    corr_matrix = dataset.corr()
    for i in range(len(corr_matrix.columns)):
        for j in range(i):
            if abs(corr_matrix.iloc[i, j]) >= threshold: # we are interested in absolute coeff value
                colname = corr_matrix.columns[i]  # getting the name of column
                col_corr.add(colname)
    return col_corr

# %%
corr_features = correlation(df, 0.7)
len(set(corr_features))
# Out:
# 32

# %%
corr_features
# Out:
# {'android.sensor.accelerometer#max',
#  'android.sensor.accelerometer#std',
#  'android.sensor.game_rotation_vector#max',
#  'android.sensor.game_rotation_vector#min',
#  'android.sensor.gravity#max',
#  'android.sensor.gravity#min',
#  'android.sensor.gyroscope#max',
#  'android.sensor.gyroscope#mean',
#  'android.sensor.gyroscope#min',
#  'android.sensor.gyroscope#std',
#  'android.sensor.gyroscope_uncalibrated#max',
#  'android.sensor.gyroscope_uncalibrated#mean',
#  'android.sensor.gyroscope_uncalibrated#min',
#  'android.sensor.gyroscope_uncalibrated#std',
#  'android.sensor.light#max',
#  'android.sensor.light#min',
#  'android.sensor.linear_acceleration#max',
#  'android.sensor.linear_acceleration#mean',
#  'android.sensor.linear_acceleration#min',
#  'android.sensor.linear_acceleration#std',
#  'android.sensor.magnetic_field#max',
#  'android.sensor.magnetic_field#min',
#  'android.sensor.magnetic_field_uncalibrated#max',
#  'android.sensor.magnetic_field_uncalibrated#min',
#  'android.sensor.orientation#max',
#  'android.sensor.orientation#min',
#  'android.sensor.rotation_vector#max',
#  'android.sensor.rotation_vector#min',
#  'sound#max',
#  'sound#min',
#  'speed#max',
#  'speed#min'}

# %%
df1 = df.drop(corr_features,axis=1)

# %%
df1
# Out:
#       time  activityrecognition#1  android.sensor.accelerometer#mean  \
# 0       78                    100                           9.811476
# 1      145                    100                           9.939207
# 2      150                    100                           9.827178
# 3      105                     77                           9.673039
# 4       77                    100                           9.993466
# ...    ...                    ...                                ...
# 5888     4                    100                          10.066610
# 5889    32                     10                           9.964271
# 5890    86                    100                           9.812893
# 5891   199                    100                           9.831144
# 5892    55                    100                          11.051009
#
#       android.sensor.accelerometer#min  \
# 0                             9.758895
# 1                             7.707437
# 2                             9.804817
# 3                             7.659674
# 4                             8.965621
# ...                                ...
# 5888                          4.564648
# 5889                          8.768007
# 5890                          9.772881
# 5891                          9.807347
# 5892                          5.203285
#
#       android.sensor.game_rotation_vector#mean  \
# 0                                     0.029340
# 1                                     0.999925
# 2                                     0.665215
# 3                                     0.996221
# 4                                     0.563792
# ...                                        ...
# 5888                                  0.986319
# 5889                                  0.648602
# 5890                                  0.024392
# 5891                                  0.481212
# 5892                                  0.919815
#
#       android.sensor.game_rotation_vector#std  android.sensor.gravity#mean  \
# 0                                    0.000119                     9.806650
# 1                                    0.000030                     9.806624
# 2                                    0.000004                     9.806650
# 3                                    0.003451                     9.806638
# 4                                    0.064792                     9.806650
# ...                                       ...                          ...
# 5888                                 0.007186                     9.806650
# 5889                                 0.000331                     9.806650
# 5890                                 0.000211                     9.806650
# 5891                                 0.000002                     9.806621
# 5892                                 0.019459                     9.806650
#
#       android.sensor.gravity#std  android.sensor.light#mean  \
# 0                   4.780000e-07                      0.000
# 1                   6.470000e-07                      0.000
# 2                   2.820000e-07                      2.000
# 3                   2.120000e-06                      0.000
# 4                   2.640000e-07                     30.000
# ...                          ...                        ...
# 5888                2.230000e-07                      4.000
# 5889                8.170000e-07                    126.123
# 5890                4.290000e-07                      0.000
# 5891                2.930000e-05                     16.000
# 5892                3.590000e-07                      0.000
#
#       android.sensor.magnetic_field#mean  ...  \
# 0                              57.099638  ...
# 1                              29.351288  ...
# 2                              29.904927  ...
# 3                              37.836471  ...
# 4                              78.375718  ...
# ...                                  ...  ...
# 5888                           28.551588  ...
# 5889                           40.665641  ...
# 5890                           57.026001  ...
# 5891                           62.277008  ...
# 5892                           43.983419  ...
#
#       android.sensor.magnetic_field_uncalibrated#mean  \
# 0                                           51.363566
# 1                                           82.767760
# 2                                           55.695716
# 3                                           95.743821
# 4                                          157.429217
# ...                                               ...
# 5888                                        56.502261
# 5889                                        85.122017
# 5890                                        51.317797
# 5891                                       270.495205
# 5892                                       149.048369
#
#       android.sensor.magnetic_field_uncalibrated#std  \
# 0                                           0.080899
# 1                                           0.506105
# 2                                           0.128945
# 3                                           0.112446
# 4                                           0.895633
# ...                                              ...
# 5888                                       23.640120
# 5889                                        4.265621
# 5890                                        0.074212
# 5891                                        0.235700
# 5892                                        0.054675
#
#       android.sensor.orientation#mean  android.sensor.orientation#std  \
# 0                          354.286933                        0.245676
# 1                          332.695577                        1.705816
# 2                           74.752653                        0.413704
# 3                          373.556039                        8.870011
# 4                          193.201458                      181.729455
# ...                               ...                             ...
# 5888                       198.025171                        0.858121
# 5889                        35.427524                        1.794702
# 5890                       354.182815                        0.307487
# 5891                        32.077433                        0.000209
# 5892                       260.716040                      128.622821
#
#       android.sensor.rotation_vector#mean  android.sensor.rotation_vector#std  \
# 0                                0.050413                            0.002109
# 1                                0.999981                            0.000026
# 2                                0.610456                            0.011312
# 3                                0.998112                            0.002788
# 4                                0.322242                            0.025608
# ...                                   ...                                 ...
# 5888                             0.932682                            0.008767
# 5889                             0.295905                            0.018447
# 5890                             0.051333                            0.002659
# 5891                             0.276348                            0.000005
# 5892                             0.990902                            0.003996
#
#       sound#mean  sound#std  speed#mean  target
# 0       0.000000   0.000000    0.000000       2
# 1      89.200210   0.191013   16.539349       1
# 2       0.000000   0.000000    0.000000       2
# 3      87.470377   2.284186   17.739895       1
# 4      89.770732   0.006389    9.000000       1
# ...          ...        ...         ...     ...
# 5888    0.000000   0.000000    0.000000       4
# 5889    0.000000   0.000000   31.960054       3
# 5890    0.000000   0.000000    0.000000       2
# 5891    0.000000   0.000000    1.090415       2
# 5892   89.712441   0.006400    0.750000       4
#
# [5893 rows x 21 columns]

# %%
corr = df1.corr()

plt.figure(figsize=(8,8))  
sns.heatmap(corr, annot = False, cmap = 'coolwarm')
# Out:
# <Axes: >

# %%
#from sklearn.preprocessing import OneHotEncoder
#enc = OneHotEncoder(handle_unknown='ignore')

#enc_df = pd.DataFrame(enc.fit_transform(df1[['target']]).toarray())

#final_df = df1.join(enc_df)

# %%
final_df = df1

# %%
final_df
# Out:
#       time  activityrecognition#1  android.sensor.accelerometer#mean  \
# 0       78                    100                           9.811476
# 1      145                    100                           9.939207
# 2      150                    100                           9.827178
# 3      105                     77                           9.673039
# 4       77                    100                           9.993466
# ...    ...                    ...                                ...
# 5888     4                    100                          10.066610
# 5889    32                     10                           9.964271
# 5890    86                    100                           9.812893
# 5891   199                    100                           9.831144
# 5892    55                    100                          11.051009
#
#       android.sensor.accelerometer#min  \
# 0                             9.758895
# 1                             7.707437
# 2                             9.804817
# 3                             7.659674
# 4                             8.965621
# ...                                ...
# 5888                          4.564648
# 5889                          8.768007
# 5890                          9.772881
# 5891                          9.807347
# 5892                          5.203285
#
#       android.sensor.game_rotation_vector#mean  \
# 0                                     0.029340
# 1                                     0.999925
# 2                                     0.665215
# 3                                     0.996221
# 4                                     0.563792
# ...                                        ...
# 5888                                  0.986319
# 5889                                  0.648602
# 5890                                  0.024392
# 5891                                  0.481212
# 5892                                  0.919815
#
#       android.sensor.game_rotation_vector#std  android.sensor.gravity#mean  \
# 0                                    0.000119                     9.806650
# 1                                    0.000030                     9.806624
# 2                                    0.000004                     9.806650
# 3                                    0.003451                     9.806638
# 4                                    0.064792                     9.806650
# ...                                       ...                          ...
# 5888                                 0.007186                     9.806650
# 5889                                 0.000331                     9.806650
# 5890                                 0.000211                     9.806650
# 5891                                 0.000002                     9.806621
# 5892                                 0.019459                     9.806650
#
#       android.sensor.gravity#std  android.sensor.light#mean  \
# 0                   4.780000e-07                      0.000
# 1                   6.470000e-07                      0.000
# 2                   2.820000e-07                      2.000
# 3                   2.120000e-06                      0.000
# 4                   2.640000e-07                     30.000
# ...                          ...                        ...
# 5888                2.230000e-07                      4.000
# 5889                8.170000e-07                    126.123
# 5890                4.290000e-07                      0.000
# 5891                2.930000e-05                     16.000
# 5892                3.590000e-07                      0.000
#
#       android.sensor.magnetic_field#mean  ...  \
# 0                              57.099638  ...
# 1                              29.351288  ...
# 2                              29.904927  ...
# 3                              37.836471  ...
# 4                              78.375718  ...
# ...                                  ...  ...
# 5888                           28.551588  ...
# 5889                           40.665641  ...
# 5890                           57.026001  ...
# 5891                           62.277008  ...
# 5892                           43.983419  ...
#
#       android.sensor.magnetic_field_uncalibrated#mean  \
# 0                                           51.363566
# 1                                           82.767760
# 2                                           55.695716
# 3                                           95.743821
# 4                                          157.429217
# ...                                               ...
# 5888                                        56.502261
# 5889                                        85.122017
# 5890                                        51.317797
# 5891                                       270.495205
# 5892                                       149.048369
#
#       android.sensor.magnetic_field_uncalibrated#std  \
# 0                                           0.080899
# 1                                           0.506105
# 2                                           0.128945
# 3                                           0.112446
# 4                                           0.895633
# ...                                              ...
# 5888                                       23.640120
# 5889                                        4.265621
# 5890                                        0.074212
# 5891                                        0.235700
# 5892                                        0.054675
#
#       android.sensor.orientation#mean  android.sensor.orientation#std  \
# 0                          354.286933                        0.245676
# 1                          332.695577                        1.705816
# 2                           74.752653                        0.413704
# 3                          373.556039                        8.870011
# 4                          193.201458                      181.729455
# ...                               ...                             ...
# 5888                       198.025171                        0.858121
# 5889                        35.427524                        1.794702
# 5890                       354.182815                        0.307487
# 5891                        32.077433                        0.000209
# 5892                       260.716040                      128.622821
#
#       android.sensor.rotation_vector#mean  android.sensor.rotation_vector#std  \
# 0                                0.050413                            0.002109
# 1                                0.999981                            0.000026
# 2                                0.610456                            0.011312
# 3                                0.998112                            0.002788
# 4                                0.322242                            0.025608
# ...                                   ...                                 ...
# 5888                             0.932682                            0.008767
# 5889                             0.295905                            0.018447
# 5890                             0.051333                            0.002659
# 5891                             0.276348                            0.000005
# 5892                             0.990902                            0.003996
#
#       sound#mean  sound#std  speed#mean  target
# 0       0.000000   0.000000    0.000000       2
# 1      89.200210   0.191013   16.539349       1
# 2       0.000000   0.000000    0.000000       2
# 3      87.470377   2.284186   17.739895       1
# 4      89.770732   0.006389    9.000000       1
# ...          ...        ...         ...     ...
# 5888    0.000000   0.000000    0.000000       4
# 5889    0.000000   0.000000   31.960054       3
# 5890    0.000000   0.000000    0.000000       2
# 5891    0.000000   0.000000    1.090415       2
# 5892   89.712441   0.006400    0.750000       4
#
# [5893 rows x 21 columns]

# %%
X = final_df.iloc[:,0:20] 
y = final_df.iloc[:,20]

# %%
X
# Out:
#       time  activityrecognition#1  android.sensor.accelerometer#mean  \
# 0       78                    100                           9.811476
# 1      145                    100                           9.939207
# 2      150                    100                           9.827178
# 3      105                     77                           9.673039
# 4       77                    100                           9.993466
# ...    ...                    ...                                ...
# 5888     4                    100                          10.066610
# 5889    32                     10                           9.964271
# 5890    86                    100                           9.812893
# 5891   199                    100                           9.831144
# 5892    55                    100                          11.051009
#
#       android.sensor.accelerometer#min  \
# 0                             9.758895
# 1                             7.707437
# 2                             9.804817
# 3                             7.659674
# 4                             8.965621
# ...                                ...
# 5888                          4.564648
# 5889                          8.768007
# 5890                          9.772881
# 5891                          9.807347
# 5892                          5.203285
#
#       android.sensor.game_rotation_vector#mean  \
# 0                                     0.029340
# 1                                     0.999925
# 2                                     0.665215
# 3                                     0.996221
# 4                                     0.563792
# ...                                        ...
# 5888                                  0.986319
# 5889                                  0.648602
# 5890                                  0.024392
# 5891                                  0.481212
# 5892                                  0.919815
#
#       android.sensor.game_rotation_vector#std  android.sensor.gravity#mean  \
# 0                                    0.000119                     9.806650
# 1                                    0.000030                     9.806624
# 2                                    0.000004                     9.806650
# 3                                    0.003451                     9.806638
# 4                                    0.064792                     9.806650
# ...                                       ...                          ...
# 5888                                 0.007186                     9.806650
# 5889                                 0.000331                     9.806650
# 5890                                 0.000211                     9.806650
# 5891                                 0.000002                     9.806621
# 5892                                 0.019459                     9.806650
#
#       android.sensor.gravity#std  android.sensor.light#mean  \
# 0                   4.780000e-07                      0.000
# 1                   6.470000e-07                      0.000
# 2                   2.820000e-07                      2.000
# 3                   2.120000e-06                      0.000
# 4                   2.640000e-07                     30.000
# ...                          ...                        ...
# 5888                2.230000e-07                      4.000
# 5889                8.170000e-07                    126.123
# 5890                4.290000e-07                      0.000
# 5891                2.930000e-05                     16.000
# 5892                3.590000e-07                      0.000
#
#       android.sensor.magnetic_field#mean  android.sensor.magnetic_field#std  \
# 0                              57.099638                           0.177549
# 1                              29.351288                           0.921547
# 2                              29.904927                           0.130851
# 3                              37.836471                           0.439461
# 4                              78.375718                           1.104361
# ...                                  ...                                ...
# 5888                           28.551588                           0.381842
# 5889                           40.665641                           1.755636
# 5890                           57.026001                           0.209266
# 5891                           62.277008                           0.636157
# 5892                           43.983419                           1.073626
#
#       android.sensor.magnetic_field_uncalibrated#mean  \
# 0                                           51.363566
# 1                                           82.767760
# 2                                           55.695716
# 3                                           95.743821
# 4                                          157.429217
# ...                                               ...
# 5888                                        56.502261
# 5889                                        85.122017
# 5890                                        51.317797
# 5891                                       270.495205
# 5892                                       149.048369
#
#       android.sensor.magnetic_field_uncalibrated#std  \
# 0                                           0.080899
# 1                                           0.506105
# 2                                           0.128945
# 3                                           0.112446
# 4                                           0.895633
# ...                                              ...
# 5888                                       23.640120
# 5889                                        4.265621
# 5890                                        0.074212
# 5891                                        0.235700
# 5892                                        0.054675
#
#       android.sensor.orientation#mean  android.sensor.orientation#std  \
# 0                          354.286933                        0.245676
# 1                          332.695577                        1.705816
# 2                           74.752653                        0.413704
# 3                          373.556039                        8.870011
# 4                          193.201458                      181.729455
# ...                               ...                             ...
# 5888                       198.025171                        0.858121
# 5889                        35.427524                        1.794702
# 5890                       354.182815                        0.307487
# 5891                        32.077433                        0.000209
# 5892                       260.716040                      128.622821
#
#       android.sensor.rotation_vector#mean  android.sensor.rotation_vector#std  \
# 0                                0.050413                            0.002109
# 1                                0.999981                            0.000026
# 2                                0.610456                            0.011312
# 3                                0.998112                            0.002788
# 4                                0.322242                            0.025608
# ...                                   ...                                 ...
# 5888                             0.932682                            0.008767
# 5889                             0.295905                            0.018447
# 5890                             0.051333                            0.002659
# 5891                             0.276348                            0.000005
# 5892                             0.990902                            0.003996
#
#       sound#mean  sound#std  speed#mean
# 0       0.000000   0.000000    0.000000
# 1      89.200210   0.191013   16.539349
# 2       0.000000   0.000000    0.000000
# 3      87.470377   2.284186   17.739895
# 4      89.770732   0.006389    9.000000
# ...          ...        ...         ...
# 5888    0.000000   0.000000    0.000000
# 5889    0.000000   0.000000   31.960054
# 5890    0.000000   0.000000    0.000000
# 5891    0.000000   0.000000    1.090415
# 5892   89.712441   0.006400    0.750000
#
# [5893 rows x 20 columns]

# %%
y
# Out:
# 0       2
# 1       1
# 2       2
# 3       1
# 4       1
#        ..
# 5888    4
# 5889    3
# 5890    2
# 5891    2
# 5892    4
# Name: target, Length: 5893, dtype: int64

# %%
type(y)
# Out:
# pandas.core.series.Series

# %%
from sklearn.preprocessing import MinMaxScaler   #min max scaling

scaler = MinMaxScaler(feature_range=(0,1))

scaler.fit(X)

X_scaled = scaler.transform(X)

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test =train_test_split(X_scaled,y,test_size=0.2)

# %%
type(X_train)
# Out:
# numpy.ndarray

# %%
type(y_train)
# Out:
# pandas.core.series.Series

# %%
y_train.shape
# Out:
# (4714,)

# %%
from re import L

def create_clients(feature_list, label_list, num_clients=5, initial='clients'):
    ''' return: a dictionary with keys clients' names and value as 
                data shards - tuple of features and label lists.
        args: 
            feature_list: a list of numpy arrays of training features
            label_list:a list of binarized labels for each feature
            num_client: number of fedrated members (clients)
            initials: the clients'name prefix, e.g, clients_1 
            
    '''

    #create a list of client names
    client_names = ['{}_{}'.format(initial, i+1) for i in range(num_clients)]

    #randomize the data
    print(len(feature_list))
    print(len(label_list))
    data = list(zip(feature_list, label_list))
    print(len(data))
    random.shuffle(data)
    #shard data and place at each client
    size = len(data)//num_clients
    shards = [data[i:i + size] for i in range(0, size*num_clients, size)]

    #number of clients must equal number of shards
    assert(len(shards) == len(client_names))

    return {client_names[i] : shards[i] for i in range(len(client_names))}

# %%
X_train.shape
# Out:
# (4714, 20)

# %%
#create clients
clients = create_clients(X_train, y_train, num_clients=5, initial='client')
# Out:
# 4714
# 4714
# 4714

# %%
len(clients['client_3'])

# add-on
n = 1
for c in clients:
  print(str(n),":",len(clients[c]))
  n+=1
# Out:
# 1 : 942
# 2 : 942
# 3 : 942
# 4 : 942
# 5 : 942

# %%
def batch_data(data_shard, bs=32):
    '''Takes in a clients data shard and create a tfds object off it
    args:
        shard: a data, label constituting a client's data shard
        bs:batch size
    return:
        tfds object'''
    #seperate shard into data and labels lists
    data, label = zip(*data_shard)
    dataset = tf.data.Dataset.from_tensor_slices((list(data), list(label)))
    return dataset.shuffle(len(label)).batch(bs)

# %%
#process and batch the training data for each client
clients_batched = dict()
for (client_name, data) in clients.items():
    clients_batched[client_name] = batch_data(data)
    
#process and batch the test set  
test_batched = tf.data.Dataset.from_tensor_slices((X_test, y_test)).batch(len(y_test))
# Out:
# 2025-12-10 15:11:01.254629: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:887] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2025-12-10 15:11:01.254755: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:887] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2025-12-10 15:11:01.254790: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:887] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2025-12-10 15:11:01.254800: W tensorflow/core/common_runtime/gpu/gpu_device.cc:2348] TensorFlow was not built with CUDA kernel binaries compatible with compute capability 12.0. CUDA kernels will be jit-compiled from PTX, which could take 30 minutes or longer.
# 2025-12-10 15:11:01.255359: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:887] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2025-12-10 15:11:01.255381: I tensorflow/core/common_runtime/gpu/gpu_device.cc:2022] Could not identify NUMA node of platform GPU id 0, defaulting to 0.  Your kernel may not have been built with NUMA support.
# 2025-12-10 15:11:01.255406: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:887] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2025-12-10 15:11:01.255422: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1929] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 13067 MB memory:  -> device: 0, name: NVIDIA GeForce RTX 5080, pci bus id: 0000:01:00.0, compute capability: 12.0

# %%
class SimpleMLP:
    @staticmethod
    def build(shape, classes):
        model = Sequential()
        model.add(Dense(256, input_shape=(20,)))
        model.add(Activation("relu"))
        model.add(Dropout(0.40))
        model.add(Dense(256))
        model.add(Activation("relu"))
        model.add(Dropout(0.40))
        model.add(Dense(5))
        model.add(Activation("softmax"))
        return model

# %%
# new version of tf.keras.optimizer.SGD hasn't support decay function
# lr = 0.01 
# comms_round = 200
# loss='sparse_categorical_crossentropy'
# metrics = ['sparse_categorical_accuracy']
# optimizer = SGD(learning_rate=lr, 
#                 decay=lr / comms_round, 
#                 momentum=0.9)  
# here attempt to use legacy instead
from tensorflow.keras.optimizers import legacy as legacy_optimizers

lr = 0.01 
comms_round = 200
loss='sparse_categorical_crossentropy'
metrics = ['sparse_categorical_accuracy']
optimizer = legacy_optimizers.SGD(learning_rate=lr, 
                decay=lr / comms_round, 
                momentum=0.9)

# %%
def weight_scalling_factor(clients_trn_data, client_name):
    client_names = list(clients_trn_data.keys())
    #get the bs
    bs = list(clients_trn_data[client_name])[0][0].shape[0]
    #first calculate the total training data points across clinets
    global_count = sum([tf.data.experimental.cardinality(clients_trn_data[client_name]).numpy() for client_name in client_names])*bs
    # get the total number of data points held by a client
    local_count = tf.data.experimental.cardinality(clients_trn_data[client_name]).numpy()*bs
    return local_count/global_count


def scale_model_weights(weight, scalar):
    '''function for scaling a models weights'''
    weight_final = []
    steps = len(weight)
    for i in range(steps):
        weight_final.append(scalar * weight[i])
    return weight_final



def sum_scaled_weights(scaled_weight_list):
    '''Return the sum of the listed scaled weights. The is equivalent to scaled avg of the weights'''
    avg_grad = list()
    #get the average grad accross all client gradients
    for grad_list_tuple in zip(*scaled_weight_list):
        layer_mean = tf.math.reduce_sum(grad_list_tuple, axis=0)
        avg_grad.append(layer_mean)
        
    return avg_grad


def test_model(X_test, Y_test,  model1, model2, model3, comm_round):
    y_pred = []
    cce = tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True)
    #logits = model.predict(X_test, batch_size=100)
    logits1 = model1.predict(X_test)
    logits2 = model2.predict(X_test)
    logits3 = model3.predict(X_test)
    #print(Y_test)
    c1 = tf.argmax(logits1, axis=1).numpy()
    #c2 = tf.argmax(logits2, axis=1)
    #c3 = tf.argmax(logits3, axis=1)
    #c1 = logits1
    c2 = logits2
    c3 = logits3
    print(c1)
    print(c2)
    print(c3)
    for i in range(len(c1)):
        tmp = []
        tmp.append(c1[i])
        tmp.append(c2[i])
        tmp.append(c3[i])
        #print(tmp)
        y_pred.append(np.bincount(tmp).argmax())
    Y_test = np.squeeze(Y_test)

    y_pred = np.array(y_pred)



    acc = accuracy_score(y_pred, Y_test)
    print(y_pred.shape)
    print(Y_test.shape)
    #loss = cce(y_pred, Y_test)

    print('comm_round: {} | global_acc: {:.3%}'.format(comm_round, acc))
    cf=classification_report(Y_test,y_pred)
    print(cf)
    return acc, loss

# %%
import joblib
import sklearn.pipeline

# %%
#initialize global model
smlp_global = SimpleMLP()
global_model1 = smlp_global.build(20, 5)
global_model2 = XGBClassifier()
global_model3 = RandomForestClassifier()

local_model2 = XGBClassifier()
local_model3 = RandomForestClassifier() 


#commence global training loop
for comm_round in range(comms_round):
            
    # get the global model's weights - will serve as the initial weights for all local models
    global_weights1 = global_model1.get_weights()
    #global_weights2 = global_model2.get_weights()
    #global_weights3 = global_model3.get_weights()   # what happens to the rest of the weights? #
    #collect weights for XGB
    #collect weights for RF

    #initial list to collect local model weights after scalling
    scaled_local_weight_list1 = list()
    #scaled_local_weight_list2 = list()
    #scaled_local_weight_list3 = list()
    #list for XGB
    #list for RF

    #randomize client data - using keys
    client_names= list(clients_batched.keys())
    random.shuffle(client_names)
    
    #loop through each client and create new local model
    for client in client_names:
        #print(4)
        smlp_local = SimpleMLP()
        local_model1 = smlp_local.build(20, 5)
        local_model1.compile(loss=loss, 
                      optimizer=optimizer, 
                      metrics=metrics)
        
        
        #set local model weight to the weight of the global model
        local_model1.set_weights(global_weights1)  
        #local_model2.set_weights(global_weights2) 
        #local_model3.set_weights(global_weights3)   # what happens to the rest of the weights? #
        #set weights for the other two
        #print(clients_batched[client])
        Samples = []
        labels = []

        for x,y in clients_batched[client]:
            temp = x.numpy().tolist()
            temp2 = y.numpy().tolist()
            for i in temp:
                Samples.append(i)
            for i in temp2:
                labels.append(i)
        arr = np.array(Samples)
        labelpd = pd.Series(labels)
        #local_model1.fit(clients_batched[client], epochs=1, verbose=1)
        local_model1.fit(arr, labelpd, epochs=1, verbose=1)
        local_model2.fit(arr, labelpd)
        local_model3.fit(arr, labelpd)      

        #scale the model weights and add to list
        scaling_factor = weight_scalling_factor(clients_batched, client)
        scaled_weights1 = scale_model_weights(local_model1.get_weights(), scaling_factor)  # what happens here? #
        #scaled_weights2 = scale_model_weights(local_model2.get_weights(), scaling_factor) 
        #scaled_weights3 = scale_model_weights(local_model3.get_weights(), scaling_factor) 
        scaled_local_weight_list1.append(scaled_weights1)
        #scaled_local_weight_list2.append(scaled_weights2)
        #scaled_local_weight_list3.append(scaled_weights3)
        
        #clear session to free memory after each communication round
        K.clear_session()
    global_model2 = local_model2
    global_model3 = local_model3
     
    #to get the average over all the local model, we simply take the sum of the scaled weights
    average_weights1 = sum_scaled_weights(scaled_local_weight_list1)
    #average_weights2 = sum_scaled_weights(scaled_local_weight_list2)
    #average_weights3 = sum_scaled_weights(scaled_local_weight_list3)
    #print(average_weights)
    #update global model 
    global_model1.set_weights(average_weights1)
    #global_model2.set_weights(average_weights2)
    #global_model3.set_weights(average_weights3)

    #test global model and print out metrics after each communications round
    for(X_test, Y_test) in test_batched:
        #joblib.dump(pipeline, "xgb1.joblib.dat")
        #loaded_model = joblib.load("xgb1.joblib.dat")
        global_acc, global_loss = test_model(X_test, Y_test, global_model1, global_model2, global_model3, comm_round)  # which global model to pass here? #
# Out:
# 2025-12-10 15:56:25.616064: I external/local_tsl/tsl/platform/default/subprocess.cc:304] Start cannot spawn child process: No such file or directory
# 2025-12-10 15:56:25.650615: W external/local_xla/xla/stream_executor/gpu/asm_compiler.cc:225] Falling back to the CUDA driver for PTX compilation; ptxas does not support CC 12.0
# 2025-12-10 15:56:25.650643: W external/local_xla/xla/stream_executor/gpu/asm_compiler.cc:228] Used ptxas at /mnt/e/00_workspace/baseline_unmodified/FEL_TMD_VEN/Federated-Ensemble-Learning/venvs/tf15_py310/lib/python3.10/site-packages/tensorflow/python/platform/../../../nvidia/cuda_nvcc/bin/ptxas
# 2025-12-10 15:56:25.650683: W tensorflow/compiler/mlir/tools/kernel_gen/transforms/gpu_kernel_to_blob_pass.cc:191] Failed to compile generated PTX with ptxas. Falling back to compilation by driver.
# 2025-12-10 15:56:25.805039: W tensorflow/compiler/mlir/tools/kernel_gen/transforms/gpu_kernel_to_blob_pass.cc:191] Failed to compile generated PTX with ptxas. Falling back to compilation by driver.
# 2025-12-10 15:56:25.805178: W tensorflow/compiler/mlir/tools/kernel_gen/transforms/gpu_kernel_to_blob_pass.cc:191] Failed to compile generated PTX with ptxas. Falling back to compilation by driver.
# 2025-12-10 15:56:25.805235: W tensorflow/compiler/mlir/tools/kernel_gen/transforms/gpu_kernel_to_blob_pass.cc:191] Failed to compile generated PTX with ptxas. Falling back to compilation by driver.
# 2025-12-10 15:56:25.805248: W tensorflow/compiler/mlir/tools/kernel_gen/transforms/gpu_kernel_to_blob_pass.cc:191] Failed to compile generated PTX with ptxas. Falling back to compilation by driver.
# 2025-12-10 15:56:25.805269: W tensorflow/compiler/mlir/tools/kernel_gen/transforms/gpu_kernel_to_blob_pass.cc:191] Failed to compile generated PTX with ptxas. Falling back to compilation by driver.
# 2025-12-10 15:56:25.805334: W tensorflow/compiler/mlir/tools/kernel_gen/transforms/gpu_kernel_to_blob_pass.cc:191] Failed to compile generated PTX with ptxas. Falling back to compilation by driver.
# 2025-12-10 15:56:25.805368: W tensorflow/compiler/mlir/tools/kernel_gen/transforms/gpu_kernel_to_blob_pass.cc:191] Failed to compile generated PTX with ptxas. Falling back to compilation by driver.
# 2025-12-10 15:56:25.805489: W tensorflow/compiler/mlir/tools/kernel_gen/transforms/gpu_kernel_to_blob_pass.cc:191] Failed to compile generated PTX with ptxas. Falling back to compilation by driver.
# 2025-12-10 15:56:25.805787: W tensorflow/compiler/mlir/tools/kernel_gen/transforms/gpu_kernel_to_blob_pass.cc:191] Failed to compile generated PTX with ptxas. Falling back to compilation by driver.
# 30/30 [==============================] - 18s 77ms/step - loss: 1.6002 - sparse_categorical_accuracy: 0.2431
# 30/30 [==============================] - 0s 3ms/step - loss: 1.6133 - sparse_categorical_accuracy: 0.2081
# 30/30 [==============================] - 0s 3ms/step - loss: 1.6072 - sparse_categorical_accuracy: 0.2442
# 30/30 [==============================] - 0s 3ms/step - loss: 1.6053 - sparse_categorical_accuracy: 0.2197
# 30/30 [==============================] - 0s 3ms/step - loss: 1.6087 - sparse_categorical_accuracy: 0.2304
# 37/37 [==============================] - 0s 1ms/step
# [3 2 2 ... 3 3 3]
# [0 1 2 ... 4 1 0]
# [0 1 2 ... 4 1 4]
# (1179,)
# (1179,)
# comm_round: 0 | global_acc: 92.706%
#               precision    recall  f1-score   support
#
#            0       0.87      0.97      0.92       256
#            1       0.92      0.88      0.90       243
#            2       0.93      0.95      0.94       220
#            3       0.95      0.95      0.95       219
#            4       0.98      0.89      0.93       241
#
#     accuracy                           0.93      1179
#    macro avg       0.93      0.93      0.93      1179
# weighted avg       0.93      0.93      0.93      1179
#
# 30/30 [==============================] - 0s 3ms/step - loss: 1.5618 - sparse_categorical_accuracy: 0.3089
# 30/30 [==============================] - 0s 3ms/step - loss: 1.5728 - sparse_categorical_accuracy: 0.2909
# 30/30 [==============================] - 0s 3ms/step - loss: 1.5663 - sparse_categorical_accuracy: 0.3132
# 30/30 [==============================] - 0s 3ms/step - loss: 1.5682 - sparse_categorical_accuracy: 0.2887
# 30/30 [==============================] - 0s 3ms/step - loss: 1.5603 - sparse_categorical_accuracy: 0.3355
# 37/37 [==============================] - 0s 1ms/step
# [0 2 2 ... 4 1 4]
# [0 1 2 ... 4 1 4]
# [0 1 2 ... 4 1 0]
# (1179,)
# (1179,)
# comm_round: 1 | global_acc: 93.045%
#               precision    recall  f1-score   support
#
#            0       0.90      0.95      0.92       256
#            1       0.92      0.89      0.91       243
#            2       0.94      0.97      0.95       220
#            3       0.98      0.90      0.94       219
#            4       0.93      0.94      0.93       241
#
#     accuracy                           0.93      1179
#    macro avg       0.93      0.93      0.93      1179
# weighted avg       0.93      0.93      0.93      1179
#
# 30/30 [==============================] - 0s 3ms/step - loss: 1.5212 - sparse_categorical_accuracy: 0.3631
# 30/30 [==============================] - 0s 3ms/step - loss: 1.5325 - sparse_categorical_accuracy: 0.3737
# 30/30 [==============================] - 0s 3ms/step - loss: 1.5366 - sparse_categorical_accuracy: 0.3333
# 30/30 [==============================] - 0s 3ms/step - loss: 1.5229 - sparse_categorical_accuracy: 0.3556
# 30/30 [==============================] - 0s 3ms/step - loss: 1.5394 - sparse_categorical_accuracy: 0.3365
# 37/37 [==============================] - 0s 1ms/step
# [3 2 2 ... 4 1 4]
# [0 1 2 ... 4 1 0]
# [0 1 2 ... 4 1 3]
# (1179,)
# (1179,)
# comm_round: 2 | global_acc: 93.384%
#               precision    recall  f1-score   support
#
#            0       0.89      0.98      0.93
#               precision    recall  f1-score   support
#
#            0       0.92      0.96      0.94       256
#            1       0.95      0.90      0.92       243
#            2       0.94      0.97      0.96       220
#            3       0.97      0.95      0.96       219
#            4       0.93      0.94      0.94       241
#
#     accuracy                           0.94      1179
#    macro avg       0.94      0.94      0.94      1179
# weighted avg       0.94      0.94      0.94      1179
#
# 30/30 [==============================] - 0s 3ms/step - loss: 0.4388 - sparse_categorical_accuracy: 0.8450
# 30/30 [==============================] - 0s 3ms/step - loss: 0.4068 - sparse_categorical_accuracy: 0.8567
# 30/30 [==============================] - 0s 3ms/step - loss: 0.4475 - sparse_categorical_accuracy: 0.8376
# 30/30 [==============================] - 0s 3ms/step - loss: 0.4592 - sparse_categorical_accuracy: 0.8493
# 30/30 [==============================] - 0s 3ms/step - loss: 0.4263 - sparse_categorical_accuracy: 0.8376
# 37/37 [==============================] - 0s 1ms/step
# [0 1 2 ... 4 1 3]
# [0 1 2 ... 4 1 0]
# [0 1 2 ... 4 1 0]
# (1179,)
# (1179,)
# comm_round: 196 | global_acc: 94.148%
#               precision    recall  f1-score   support
#
#            0       0.89      0.98      0.94       256
#            1       0.92      0.90      0.91       243
#            2       0.96      0.96      0.96       220
#            3       0.98      0.94      0.96       219
#            4       0.97      0.92      0.94       241
#
#     accuracy                           0.94      1179
#    macro avg       0.94      0.94      0.94      1179
# weighted avg       0.94      0.94      0.94      1179
#
# 30/30 [==============================] - 0s 3ms/step - loss: 0.4532 - sparse_categorical_accuracy: 0.8450
# 30/30 [==============================] - 0s 3ms/step - loss: 0.3878 - sparse_categorical_accuracy: 0.8673
# 30/30 [==============================] - 0s 3ms/step - loss: 0.4306 - sparse_categorical_accuracy: 0.8535
# 30/30 [==============================] - 0s 3ms/step - loss: 0.4092 - sparse_categorical_accuracy: 0.8418
# 30/30 [==============================] - 0s 3ms/step - loss: 0.4292 - sparse_categorical_accuracy: 0.8333
# 37/37 [==============================] - 0s 1ms/step
# [0 1 2 ... 4 1 3]
# [0 1 2 ... 4 1 4]
# [0 1 2 ... 4 1 4]
# (1179,)
# (1179,)
# comm_round: 197 | global_acc: 94.826%
#               precision    recall  f1-score   support
#
#            0       0.91      0.97      0.94       256
#            1       0.98      0.87      0.92       243
#            2       0.95      0.98      0.96       220
#            3       0.95      0.97      0.96       219
#            4       0.97      0.95      0.96       241
#
#     accuracy                           0.95      1179
#    macro avg       0.95      0.95      0.95      1179
# weighted avg       0.95      0.95      0.95      1179
#
# 30/30 [==============================] - 0s 3ms/step - loss: 0.4527 - sparse_categorical_accuracy: 0.8376
# 30/30 [==============================] - 0s 3ms/step - loss: 0.4240 - sparse_categorical_accuracy: 0.8503
# 30/30 [==============================] - 0s 3ms/step - loss: 0.4473 - sparse_categorical_accuracy: 0.8376
# 30/30 [==============================] - 0s 3ms/step - loss: 0.3981 - sparse_categorical_accuracy: 0.8535
# 30/30 [==============================] - 0s 4ms/step - loss: 0.4481 - sparse_categorical_accuracy: 0.8418
# 37/37 [==============================] - 0s 1ms/step
# [0 1 2 ... 4 1 3]
# [0 1 2 ... 4 1 3]
# [0 1 2 ... 4 1 4]
# (1179,)
# (1179,)
# comm_round: 198 | global_acc: 93.723%
#               precision    recall  f1-score   support
#
#            0       0.90      0.97      0.93       256
#            1       0.96      0.85      0.90       243
#            2       0.95      0.95      0.95       220
#            3       0.96      0.96      0.96       219
#            4       0.94      0.96      0.95       241
#
#     accuracy                           0.94      1179
#    macro avg       0.94      0.94      0.94      1179
# weighted avg       0.94      0.94      0.94      1179
#
# 30/30 [==============================] - 0s 3ms/step - loss: 0.4349 - sparse_categorical_accuracy: 0.8514
# 30/30 [==============================] - 0s 3ms/step - loss: 0.4640 - sparse_categorical_accuracy: 0.8301
# 30/30 [==============================] - 0s 3ms/step - loss: 0.3914 - sparse_categorical_accuracy: 0.8747
# 30/30 [==============================] - 0s 4ms/step - loss: 0.4308 - sparse_categorical_accuracy: 0.8471
# 30/30 [==============================] - 0s 3ms/step - loss: 0.4630 - sparse_categorical_accuracy: 0.8323
# 37/37 [==============================] - 0s 1ms/step
# [0 1 2 ... 4 1 3]
# [0 1 2 ... 4 1 3]
# [0 1 2 ... 4 1 4]
# (1179,)
# (1179,)
# comm_round: 199 | global_acc: 94.402%
#               precision    recall  f1-score   support
#
#            0       0.91      0.98      0.95       256
#            1       0.97      0.86      0.91       243
#            2       0.95      0.95      0.95       220
#            3       0.95      0.96      0.96       219
#            4       0.94      0.96      0.95       241
#
#     accuracy                           0.94      1179
#    macro avg       0.95      0.94      0.94      1179
# weighted avg       0.95      0.94      0.94      1179

# %%
'''
Samples = []
labels = []

for x,y in clients_batched['client_1']:
    temp = x.numpy().tolist()
    temp2 = y.numpy().tolist()
    for i in temp:
        Samples.append(i)
    for i in temp2:
        labels.append(i)

arr = np.array(Samples)
print(arr)

           
labelpd = pd.Series(labels)
'''
# Out:
# "\nSamples = []\nlabels = []\n\nfor x,y in clients_batched['client_1']:\n    temp = x.numpy().tolist()\n    temp2 = y.numpy().tolist()\n    for i in temp:\n        Samples.append(i)\n    for i in temp2:\n        labels.append(i)\n\narr = np.array(Samples)\nprint(arr)\n\n           \nlabelpd = pd.Series(labels)\n"

# %%
#labelpd

# %%
clients_batched[client]
# Out:
# <_BatchDataset element_spec=(TensorSpec(shape=(None, 20), dtype=tf.float64, name=None), TensorSpec(shape=(None,), dtype=tf.int32, name=None))>

# %% [markdown]
# Previous Rounds

# %% [markdown]
# ![image.png](data:image/png;base64,...)
